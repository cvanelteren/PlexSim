# %%
import sys; sys.path.insert(0, '../')
import networkx as nx, numpy as np, matplotlib.pyplot as plt
from plexsim.example import Potts
n = 32
g = nx.grid_graph([n, n])
ag = np.arange(5)
m = Potts(g, agentStates = ag, t = .01, \
         )
N = 10
r = m.simulate(N).reshape(-1, n, n)
import ipywidgets as w
# %matplotlib notebook
fig, ax = plt.subplots(figsize = (2,2))
h = ax.imshow(r[0])

slider = w.IntSlider(min = 0, max = len(r) - 1)
@w.interact(t = slider)
def update(t):
    h.set_data(r[t])
    fig.canvas.flush_events()
    fig.canvas.draw()
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="200">
# interactive(children=(IntSlider(value=0, description='t', max=9), Output()), _dom_classes=('widget-interact',)…

# %%
m.t.t
assert 0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c8283518226a> in <module>
# ----> 1 m.t.t
#       2 assert 0
#
# AttributeError: 'plexsim.example.Potts' object has no attribute 't'

# %%
# m.sampleNodes(10)
fig, ax = plt.subplots()
t = np.linspace(0, 3,10)
tmp = m.magnetize(temps = t, nSamples = 1000)
ax.plot(*tmp[:2])
ax.plot(tmp[0], tmp[2])
fig.show()
